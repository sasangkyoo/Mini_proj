# %%
import requests
import pandas as pd

# %%
url = 'http://apis.data.go.kr/1360000/VilageFcstInfoService_2.0/getUltraSrtNcst'
params ={'serviceKey' : '서비스키', 'pageNo' : '1', 'numOfRows' : '1000', 'dataType' : 'XML', 'base_date' : '20210628', 'base_time' : '0600', 'nx' : '55', 'ny' : '127' }

response = requests.get(url, params=params)
print(response.content)

# %%
final = pd.read_csv('final_transformed.csv')

# %%
final.shape
# Out:
# (9150, 4)

# %%
final.duplicated(subset=['일자', '자치구']).sum()
# Out:
# np.int64(0)

# %%
final[['일자', '자치구']].isna().sum()
# Out:
# 일자     0
# 자치구    0
# dtype: int64
